# %% [markdown]
# # **Membaca File**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8')

# %% [markdown]
# ## PM2.5

# %%
pm25_raw = pd.read_csv("pm25-air-pollution.csv")

# %%
pm25_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 4 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   Entity                                                                          2100 non-null   object
#  1   Code                                                                            1960 non-null   object
#  2   Year                                                                            2100 non-null   int64
#  3   Concentrations of fine particulate matter (PM2.5) - Residence area type: Total  2100 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 65.8+ KB

# %%
pm25_raw
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2010
# 1     Afghanistan  AFG  2011
# 2     Afghanistan  AFG  2012
# 3     Afghanistan  AFG  2013
# 4     Afghanistan  AFG  2014
# ...           ...  ...   ...
# 2095     Zimbabwe  ZWE  2015
# 2096     Zimbabwe  ZWE  2016
# 2097     Zimbabwe  ZWE  2017
# 2098     Zimbabwe  ZWE  2018
# 2099     Zimbabwe  ZWE  2019
#
#       Concentrations of fine particulate matter (PM2.5) - Residence area type: Total
# 0                                              68.96605
# 1                                              66.94454
# 2                                              68.25744
# 3                                              72.18289
# 4                                              68.05715
# ...                                                 ...
# 2095                                           13.26748
# 2096                                           13.09256
# 2097                                           13.15097
# 2098                                           13.11527
# 2099                                           13.07553
#
# [2100 rows x 4 columns]

# %% [markdown]
# ## GDP

# %%
gdp_raw = pd.read_csv("API_NY.GDP.PCAP.CD_DS2_en_csv_v2_252771.csv", skiprows=4)

# %%
gdp_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            151 non-null    float64
#  5   1961            154 non-null    float64
#  6   1962            156 non-null    float64
#  7   1963            156 non-null    float64
#  8   1964            156 non-null    float64
#  9   1965            162 non-null    float64
#  10  1966            163 non-null    float64
#  11  1967            167 non-null    float64
#  12  1968            168 non-null    float64
#  13  1969            168 non-null    float64
#  14  1970            190 non-null    float64
#  15  1971            191 non-null    float64
#  16  1972            191 non-null    float64
#  17  1973            191 non-null    float64
#  18  1974            191 non-null    float64
#  19  1975            195 non-null    float64
#  20  1976            195 non-null    float64
#  21  1977            198 non-null    float64
#  22  1978            197 non-null    float64
#  23  1979            198 non-null    float64
#  24  1980            208 non-null    float64
#  25  1981            208 non-null    float64
#  26  1982            209 non-null    float64
#  27  1983            209 non-null    float64
#  28  1984            211 non-null    float64
#  29  1985            213 non-null    float64
#  30  1986            213 non-null    float64
#  31  1987            220 non-null    float64
#  32  1988            223 non-null    float64
#  33  1989            223 non-null    float64
#  34  1990            240 non-null    float64
#  35  1991            241 non-null    float64
#  36  1992            242 non-null    float64
#  37  1993            243 non-null    float64
#  38  1994            244 non-null    float64
#  39  1995            247 non-null    float64
#  40  1996            247 non-null    float64
#  41  1997            249 non-null    float64
#  42  1998            250 non-null    float64
#  43  1999            250 non-null    float64
#  44  2000            252 non-null    float64
#  45  2001            253 non-null    float64
#  46  2002            257 non-null    float64
#  47  2003            257 non-null    float64
#  48  2004            257 non-null    float64
#  49  2005            257 non-null    float64
#  50  2006            258 non-null    float64
#  51  2007            258 non-null    float64
#  52  2008            259 non-null    float64
#  53  2009            261 non-null    float64
#  54  2010            261 non-null    float64
#  55  2011            262 non-null    float64
#  56  2012            260 non-null    float64
#  57  2013            260 non-null    float64
#  58  2014            261 non-null    float64
#  59  2015            259 non-null    float64
#  60  2016            258 non-null    float64
#  61  2017            258 non-null    float64
#  62  2018            258 non-null    float64
#  63  2019            258 non-null    float64
#  64  2020            257 non-null    float64
#  65  2021            257 non-null    float64
#  66  2022            256 non-null    float64
#  67  2023            248 non-null    float64
#  68  2024            231 non-null    float64
#  69  Unnamed: 69     0 non-null      float64
# dtypes: float64(66), object(4)
# memory usage: 145.6+ KB

# %%
gdp_raw.head()
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                  Afghanistan          AFG  GDP per capita (current US$)
# 3   Africa Western and Central          AFW  GDP per capita (current US$)
# 4                       Angola          AGO  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  186.121835  186.941781  197.402402  225.440494  208.999748
# 2  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 3  NY.GDP.PCAP.CD  121.939925  127.454189  133.827044  139.008291  148.549379
# 4  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
#
#          1965  ...          2016          2017          2018          2019  \
# 0         NaN  ...  27441.529662  28440.051964  30082.127645  31096.205074
# 1  226.876513  ...   1329.807285   1520.212231   1538.901679   1493.817938
# 2         NaN  ...    522.082216    525.469771    491.337221    496.602504
# 3  155.565216  ...   1630.039447   1574.230560   1720.140280   1798.340685
# 4         NaN  ...   1807.952941   2437.259712   2538.591391   2189.855714
#
#            2020          2021          2022          2023         2024  \
# 0  22855.932320  27200.061079  30559.533535  33984.790620          NaN
# 1   1344.103210   1522.393346   1628.318944   1510.742951  1567.635839
# 2    510.787063    356.496214    357.261153    413.757895          NaN
# 3   1680.039332   1765.954788   1796.668633   1599.392983  1284.154441
# 4   1449.922867   1925.874661   2929.694455   2309.534130  2122.083690
#
#    Unnamed: 69
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 70 columns]

# %% [markdown]
# ## Population

# %%
population_raw = pd.read_csv("population.csv")

# %%
population_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16930 entries, 0 to 16929
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  16930 non-null  object
#  1   Country Code  16930 non-null  object
#  2   Year          16930 non-null  int64
#  3   Value         16930 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 529.2+ KB

# %%
population_raw.head()
# Out:
#   Country Name Country Code  Year    Value
# 0        Aruba          ABW  1960  54922.0
# 1        Aruba          ABW  1961  55578.0
# 2        Aruba          ABW  1962  56320.0
# 3        Aruba          ABW  1963  57002.0
# 4        Aruba          ABW  1964  57619.0

# %% [markdown]
# # **Cleaning**

# %% [markdown]
# ### PM2.5

# %%
pm25 = pm25_raw.rename(columns={
   "Entity": "Country",
    "Code": "Country_Code",
    "Concentrations of fine particulate matter (PM2.5) - Residence area type: Total": "PM25"
})

# Ambil data dari 2010 sampai 2019
pm25 = pm25[(pm25["Year"] >= 2010) & (pm25["Year"] <= 2019)]

# Save data clean
pm25.to_csv("clean_pm2,5.csv", index=False)

# %%
pm25.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2100 entries, 0 to 2099
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       2100 non-null   object
#  1   Country_Code  1960 non-null   object
#  2   Year          2100 non-null   int64
#  3   PM25          2100 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 65.8+ KB

# %%
pm25.head()
# Out:
#        Country Country_Code  Year      PM25
# 0  Afghanistan          AFG  2010  68.96605
# 1  Afghanistan          AFG  2011  66.94454
# 2  Afghanistan          AFG  2012  68.25744
# 3  Afghanistan          AFG  2013  72.18289
# 4  Afghanistan          AFG  2014  68.05715

# %% [markdown]
# ### GDP

# %%
# Rename kolom
gdp = gdp_raw.rename(columns={
    "Country Name": "Country",
    "Country Code": "Country_Code"
})

# Hapus kolom kosong "Unnamed: 69"
gdp = gdp.drop(columns=["Unnamed: 69"], errors="ignore")

# %%
# Mengubah dari wide ke long
gdp_long = gdp.melt(
    id_vars=["Country", "Country_Code", "Indicator Name", "Indicator Code"],
    var_name="Year",
    value_name="GDP_per_capita"
)

# Ambil data dari tahun 2010 sampai 2019
gdp_long["Year"] = gdp_long["Year"].astype(int)
gdp_long = gdp_long[(gdp_long["Year"] >= 2010) & (gdp_long["Year"] <= 2019)]

# Save data clean
gdp_long.to_csv("gdp_long.csv", index=False)

gdp_long.head()
# Out:
#                            Country Country_Code                Indicator Name  \
# 13300                        Aruba          ABW  GDP per capita (current US$)
# 13301  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 13302                  Afghanistan          AFG  GDP per capita (current US$)
# 13303   Africa Western and Central          AFW  GDP per capita (current US$)
# 13304                       Angola          AGO  GDP per capita (current US$)
#
#        Indicator Code  Year  GDP_per_capita
# 13300  NY.GDP.PCAP.CD  2010    24093.140151
# 13301  NY.GDP.PCAP.CD  2010     1601.727651
# 13302  NY.GDP.PCAP.CD  2010      560.621505
# 13303  NY.GDP.PCAP.CD  2010     1663.966937
# 13304  NY.GDP.PCAP.CD  2010     3597.342932

# %%
gdp_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2660 entries, 13300 to 15959
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         2660 non-null   object
#  1   Country_Code    2660 non-null   object
#  2   Indicator Name  2660 non-null   object
#  3   Indicator Code  2660 non-null   object
#  4   Year            2660 non-null   int64
#  5   GDP_per_capita  2595 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 145.5+ KB

# %% [markdown]
# ### Population

# %%
population = population_raw.rename(columns={
    "Country Name": "Country",
    "Country Code": "Country_Code",
    "Value": "Population"
})

# Ambil data dari tahun 2010 sampai 2019
population["Year"] = population["Year"].astype(int)
population = population[(population["Year"] >= 2010) & (population["Year"] <= 2019)]

# Save data clean
population.to_csv("clean_population.csv", index=False)

population
# Out:
#         Country Country_Code  Year  Population
# 50        Aruba          ABW  2010    101838.0
# 51        Aruba          ABW  2011    102591.0
# 52        Aruba          ABW  2012    104110.0
# 53        Aruba          ABW  2013    105675.0
# 54        Aruba          ABW  2014    106807.0
# ...         ...          ...   ...         ...
# 16921  Zimbabwe          ZWE  2015  14399013.0
# 16922  Zimbabwe          ZWE  2016  14600294.0
# 16923  Zimbabwe          ZWE  2017  14812482.0
# 16924  Zimbabwe          ZWE  2018  15034452.0
# 16925  Zimbabwe          ZWE  2019  15271368.0
#
# [2650 rows x 4 columns]

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2650 entries, 50 to 16925
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       2650 non-null   object
#  1   Country_Code  2650 non-null   object
#  2   Year          2650 non-null   int64
#  3   Population    2650 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 103.5+ KB

# %% [markdown]
# # **Pre-Processing**

# %% [markdown]
# PREPROCESSING PM2.5

# %%
# Buang Country_Code yang kosong (biasanya region bukan negara)
pm25_pp = pm25.dropna(subset=["Country_Code"])

# Pastikan tipe data Year benar
pm25_pp["Year"] = pm25_pp["Year"].astype(int)

print("=== PM2.5 AFTER PREPROCESSING ===")
display(pm25_pp.head())
print(pm25_pp.info())

pm25_pp.to_csv("preprocessed_pm2,5.csv", index=False)
# Out:
# === PM2.5 AFTER PREPROCESSING ===
# /tmp/ipython-input-4197085755.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pm25_pp["Year"] = pm25_pp["Year"].astype(int)
#        Country Country_Code  Year      PM25
# 0  Afghanistan          AFG  2010  68.96605
# 1  Afghanistan          AFG  2011  66.94454
# 2  Afghanistan          AFG  2012  68.25744
# 3  Afghanistan          AFG  2013  72.18289
# 4  Afghanistan          AFG  2014  68.05715
# <class 'pandas.core.frame.DataFrame'>
# Index: 1960 entries, 0 to 2099
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       1960 non-null   object
#  1   Country_Code  1960 non-null   object
#  2   Year          1960 non-null   int64
#  3   PM25          1960 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 76.6+ KB
# None

# %% [markdown]
# PREPROCESSING GDP

# %%
# Hapus region (yang Country_Code panjang 3 adalah negara)
gdp_pp = gdp_long[gdp_long["Country_Code"].str.len() == 3]

# Year harus integer
gdp_pp["Year"] = gdp_pp["Year"].astype(int)

print("=== GDP AFTER PREPROCESSING ===")
display(gdp_pp.head())
print(gdp_pp.info())

gdp_pp.to_csv("preprocessed_gdp.csv", index=False)
# Out:
# === GDP AFTER PREPROCESSING ===
#                            Country Country_Code                Indicator Name  \
# 13300                        Aruba          ABW  GDP per capita (current US$)
# 13301  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 13302                  Afghanistan          AFG  GDP per capita (current US$)
# 13303   Africa Western and Central          AFW  GDP per capita (current US$)
# 13304                       Angola          AGO  GDP per capita (current US$)
#
#        Indicator Code  Year  GDP_per_capita
# 13300  NY.GDP.PCAP.CD  2010    24093.140151
# 13301  NY.GDP.PCAP.CD  2010     1601.727651
# 13302  NY.GDP.PCAP.CD  2010      560.621505
# 13303  NY.GDP.PCAP.CD  2010     1663.966937
# 13304  NY.GDP.PCAP.CD  2010     3597.342932
# <class 'pandas.core.frame.DataFrame'>
# Index: 2660 entries, 13300 to 15959
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         2660 non-null   object
#  1   Country_Code    2660 non-null   object
#  2   Indicator Name  2660 non-null   object
#  3   Indicator Code  2660 non-null   object
#  4   Year            2660 non-null   int64
#  5   GDP_per_capita  2595 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 145.5+ KB
# None

# %% [markdown]
# PREPROCESSING POPULATION

# %%
population_pp = population[population["Country_Code"].str.len() == 3]

population_pp["Year"] = population_pp["Year"].astype(int)
population_pp["Population"] = population_pp["Population"].astype(float)

print("=== POPULATION AFTER PREPROCESSING ===")
display(population_pp.head())
print(population_pp.info())

population_pp.to_csv("preprocessed_population.csv", index=False)
# Out:
# === POPULATION AFTER PREPROCESSING ===
#    Country Country_Code  Year  Population
# 50   Aruba          ABW  2010    101838.0
# 51   Aruba          ABW  2011    102591.0
# 52   Aruba          ABW  2012    104110.0
# 53   Aruba          ABW  2013    105675.0
# 54   Aruba          ABW  2014    106807.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 2650 entries, 50 to 16925
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       2650 non-null   object
#  1   Country_Code  2650 non-null   object
#  2   Year          2650 non-null   int64
#  3   Population    2650 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 103.5+ KB
# None

# %% [markdown]
# # **Integrasi Data**

# %% [markdown]
# ## PM25 dengan GDP
#
# Menyatukan kolom berbasis kolom Country dan Country_Code

# %%
df = pm25.merge(gdp_long[["Country_Code", "Year", "GDP_per_capita"]],
                on=["Country_Code", "Year"],
                how="left")
df.head()
# Out:
#        Country Country_Code  Year      PM25  GDP_per_capita
# 0  Afghanistan          AFG  2010  68.96605      560.621505
# 1  Afghanistan          AFG  2011  66.94454      606.694676
# 2  Afghanistan          AFG  2012  68.25744      651.417134
# 3  Afghanistan          AFG  2013  72.18289      637.087099
# 4  Afghanistan          AFG  2014  68.05715      625.054942

# %% [markdown]
# ## PM25 dan GDP dengan Population
#
# Menyatukan kolom berbasis kolom Country dan Country_Code

# %%
final_df = df.merge(population[["Country_Code", "Year", "Population"]],
              on=["Country_Code", "Year"],
              how="left")
final_df
# Out:
#           Country Country_Code  Year      PM25  GDP_per_capita  Population
# 0     Afghanistan          AFG  2010  68.96605      560.621505  28284089.0
# 1     Afghanistan          AFG  2011  66.94454      606.694676  29347708.0
# 2     Afghanistan          AFG  2012  68.25744      651.417134  30560034.0
# 3     Afghanistan          AFG  2013  72.18289      637.087099  31622704.0
# 4     Afghanistan          AFG  2014  68.05715      625.054942  32792523.0
# ...           ...          ...   ...       ...             ...         ...
# 2095     Zimbabwe          ZWE  2015  13.26748     1386.418559  14399013.0
# 2096     Zimbabwe          ZWE  2016  13.09256     1407.420964  14600294.0
# 2097     Zimbabwe          ZWE  2017  13.15097     3448.086991  14812482.0
# 2098     Zimbabwe          ZWE  2018  13.11527     2271.852504  15034452.0
# 2099     Zimbabwe          ZWE  2019  13.07553     1683.913136  15271368.0
#
# [2100 rows x 6 columns]

# %%
# Hapus baris yang memiliki nilai kosong (NaN) pada kolom PM25, GDP, atau Population
final_df = final_df.dropna(subset=["PM25", "GDP_per_capita", "Population"])
final_df
# Out:
#           Country Country_Code  Year      PM25  GDP_per_capita  Population
# 0     Afghanistan          AFG  2010  68.96605      560.621505  28284089.0
# 1     Afghanistan          AFG  2011  66.94454      606.694676  29347708.0
# 2     Afghanistan          AFG  2012  68.25744      651.417134  30560034.0
# 3     Afghanistan          AFG  2013  72.18289      637.087099  31622704.0
# 4     Afghanistan          AFG  2014  68.05715      625.054942  32792523.0
# ...           ...          ...   ...       ...             ...         ...
# 2095     Zimbabwe          ZWE  2015  13.26748     1386.418559  14399013.0
# 2096     Zimbabwe          ZWE  2016  13.09256     1407.420964  14600294.0
# 2097     Zimbabwe          ZWE  2017  13.15097     3448.086991  14812482.0
# 2098     Zimbabwe          ZWE  2018  13.11527     2271.852504  15034452.0
# 2099     Zimbabwe          ZWE  2019  13.07553     1683.913136  15271368.0
#
# [1902 rows x 6 columns]

# %%
# Menyimpan File
final_df.to_csv("dataset_final_pm25_gdp_population.csv", index=False)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1902 entries, 0 to 2099
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         1902 non-null   object
#  1   Country_Code    1902 non-null   object
#  2   Year            1902 non-null   int64
#  3   PM25            1902 non-null   float64
#  4   GDP_per_capita  1902 non-null   float64
#  5   Population      1902 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 104.0+ KB

# %% [markdown]
# # **Feature Engineering**

# %%
# a. Hapus kolom duplikat "Country Code"
final_df = final_df.drop(columns=["Country Code"], errors="ignore")

# b. Mengurutkan berdasarkan Country dan Year
final_df = final_df.sort_values(["Country", "Year"])

# c. Menghitung selisih tahunan untuk PM2.5, GDP per kapita, dan populasi berasal dari nilai tahun sebelumnya
final_df["PM25_YoY"] = final_df.groupby("Country")["PM25"].diff()
final_df["GDP_YoY"] = final_df.groupby("Country")["GDP_per_capita"].diff()
final_df["Population_YoY"] = final_df.groupby("Country")["Population"].diff()

# d. Menghitung persentase perubahan tahunan tiap variabel.
final_df["PM25_pct"] = final_df.groupby("Country")["PM25"].pct_change()
final_df["GDP_pct"] = final_df.groupby("Country")["GDP_per_capita"].pct_change()
final_df["Population_pct"] = final_df.groupby("Country")["Population"].pct_change()

# e. Mengelompokkan nilai PM2.5
final_df["Pollution_Level"] = pd.cut(
    final_df["PM25"],
    bins=[0, 15, 35, 100],
    labels=["Low", "Moderate", "High"]
)

# f. Mengubah variabel GDP & populasi ke skala log agar grafik lebih stabil dan data tidak terlalu melebar (skew)
final_df["log_GDP"] = np.log1p(final_df["GDP_per_capita"])
final_df["log_Population"] = np.log1p(final_df["Population"])

# g. SImpan hasil future engineering ke file baru
final_df.info()
final_df.to_csv("future engineering_dataset.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1902 entries, 0 to 2099
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          1902 non-null   object
#  1   Country_Code     1902 non-null   object
#  2   Year             1902 non-null   int64
#  3   PM25             1902 non-null   float64
#  4   GDP_per_capita   1902 non-null   float64
#  5   Population       1902 non-null   float64
#  6   PM25_YoY         1710 non-null   float64
#  7   GDP_YoY          1710 non-null   float64
#  8   Population_YoY   1710 non-null   float64
#  9   PM25_pct         1710 non-null   float64
#  10  GDP_pct          1710 non-null   float64
#  11  Population_pct   1710 non-null   float64
#  12  Pollution_Level  1902 non-null   category
#  13  log_GDP          1902 non-null   float64
#  14  log_Population   1902 non-null   float64
# dtypes: category(1), float64(11), int64(1), object(2)
# memory usage: 224.9+ KB

# %%
final_df
# Out:
#           Country Country_Code  Year      PM25  GDP_per_capita  Population  \
# 0     Afghanistan          AFG  2010  68.96605      560.621505  28284089.0
# 1     Afghanistan          AFG  2011  66.94454      606.694676  29347708.0
# 2     Afghanistan          AFG  2012  68.25744      651.417134  30560034.0
# 3     Afghanistan          AFG  2013  72.18289      637.087099  31622704.0
# 4     Afghanistan          AFG  2014  68.05715      625.054942  32792523.0
# ...           ...          ...   ...       ...             ...         ...
# 2095     Zimbabwe          ZWE  2015  13.26748     1386.418559  14399013.0
# 2096     Zimbabwe          ZWE  2016  13.09256     1407.420964  14600294.0
# 2097     Zimbabwe          ZWE  2017  13.15097     3448.086991  14812482.0
# 2098     Zimbabwe          ZWE  2018  13.11527     2271.852504  15034452.0
# 2099     Zimbabwe          ZWE  2019  13.07553     1683.913136  15271368.0
#
#       PM25_YoY      GDP_YoY  Population_YoY  PM25_pct   GDP_pct  \
# 0          NaN          NaN             NaN       NaN       NaN
# 1     -2.02151    46.073171       1063619.0 -0.029312  0.082182
# 2      1.31290    44.722458       1212326.0  0.019612  0.073715
# 3      3.92545   -14.330035       1062670.0  0.057509 -0.021998
# 4     -4.12574   -12.032157       1169819.0 -0.057157 -0.018886
# ...        ...          ...             ...       ...       ...
# 2095   0.14384    14.203813        191654.0  0.010960  0.010351
# 2096  -0.17492    21.002405        201281.0 -0.013184  0.015149
# 2097   0.05841  2040.666027        212188.0  0.004461  1.449933
# 2098  -0.03570 -1176.234487        221970.0 -0.002715 -0.341127
# 2099  -0.03974  -587.939368        236916.0 -0.003030 -0.258793
#
#       Population_pct Pollution_Level   log_GDP  log_Population
# 0                NaN            High  6.330828       17.157810
# 1           0.037605            High  6.409673       17.194725
# 2           0.041309            High  6.480684       17.235204
# 3           0.034773            High  6.458475       17.269386
# 4           0.036993            High  6.439438       17.305711
# ...              ...             ...       ...             ...
# 2095        0.013490             Low  7.235200       16.482670
# 2096        0.013979             Low  7.250224       16.496552
# 2097        0.014533             Low  8.145865       16.510981
# 2098        0.014985             Low  7.728791       16.525855
# 2099        0.015758             Low  7.429469       16.541490
#
# [1902 rows x 15 columns]

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
final_df.info()
final_df.describe()
final_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1902 entries, 0 to 2099
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          1902 non-null   object
#  1   Country_Code     1902 non-null   object
#  2   Year             1902 non-null   int64
#  3   PM25             1902 non-null   float64
#  4   GDP_per_capita   1902 non-null   float64
#  5   Population       1902 non-null   float64
#  6   PM25_YoY         1710 non-null   float64
#  7   GDP_YoY          1710 non-null   float64
#  8   Population_YoY   1710 non-null   float64
#  9   PM25_pct         1710 non-null   float64
#  10  GDP_pct          1710 non-null   float64
#  11  Population_pct   1710 non-null   float64
#  12  Pollution_Level  1902 non-null   category
#  13  log_GDP          1902 non-null   float64
#  14  log_Population   1902 non-null   float64
# dtypes: category(1), float64(11), int64(1), object(2)
# memory usage: 224.9+ KB
#        Country Country_Code  Year      PM25  GDP_per_capita  Population  \
# 0  Afghanistan          AFG  2010  68.96605      560.621505  28284089.0
# 1  Afghanistan          AFG  2011  66.94454      606.694676  29347708.0
# 2  Afghanistan          AFG  2012  68.25744      651.417134  30560034.0
# 3  Afghanistan          AFG  2013  72.18289      637.087099  31622704.0
# 4  Afghanistan          AFG  2014  68.05715      625.054942  32792523.0
#
#    PM25_YoY    GDP_YoY  Population_YoY  PM25_pct   GDP_pct  Population_pct  \
# 0       NaN        NaN             NaN       NaN       NaN             NaN
# 1  -2.02151  46.073171       1063619.0 -0.029312  0.082182        0.037605
# 2   1.31290  44.722458       1212326.0  0.019612  0.073715        0.041309
# 3   3.92545 -14.330035       1062670.0  0.057509 -0.021998        0.034773
# 4  -4.12574 -12.032157       1169819.0 -0.057157 -0.018886        0.036993
#
#   Pollution_Level   log_GDP  log_Population
# 0            High  6.330828       17.157810
# 1            High  6.409673       17.194725
# 2            High  6.480684       17.235204
# 3            High  6.458475       17.269386
# 4            High  6.439438       17.305711

# %% [markdown]
# Grafik tren PM2.5 global dari 1990-2019

# %%
plt.figure(figsize=(12,6))

# Ambil 10 negara pertama agar grafik tidak terlalu ramai
country_sample = final_df['Country'].unique()[:10]

sns.lineplot(
    data=final_df[final_df['Country'].isin(country_sample)],
    x='Year',
    y='PM25',
    hue='Country',
    linewidth=2
)

plt.title("Tren PM2.5 per Negara (2010–2019)")
plt.ylabel("PM2.5")
plt.xlabel("Tahun")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig("trend_pm25.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Korelasi GDP vs PM2.5

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=final_df, x="GDP_per_capita", y="PM25", hue="Pollution_Level")
plt.title("Korelasi GDP per Kapita vs PM2.5")
plt.savefig("gdp_vs_pm25.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Korelasi Population vs PM2.5

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(
    data=final_df,
    x="Population",
    y="PM25",
    hue="Pollution_Level",
    alpha=0.7
)

plt.xscale("log")
plt.xlabel("Population (log scale)")
plt.ylabel("PM2.5 Concentration")
plt.title("Korelasi Populasi vs PM2.5")
plt.savefig("population_vs_pm25.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Bar plot negara dengan polusi tertinggi

# %%
plt.figure(figsize=(8,5))
sns.boxplot(
    data=final_df,
    x="Pollution_Level",
    y="PM25",
    palette="Set2"
)

plt.title("Distribusi PM2.5 Berdasarkan Level Polusi")
plt.xlabel("Kategori Level Polusi")
plt.ylabel("PM2.5")
plt.savefig("pollution_boxplot.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-4057526489.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# Heatmap hubungan semua variabel

# %%
plt.figure(figsize=(8,6))
sns.heatmap(final_df[["PM25","GDP_per_capita","Population"]].corr(),
            annot=True, cmap="viridis")
plt.title("Korelasi PM2.5, GDP, dan Population")
plt.savefig("correlation_heatmap.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Plot negara dengan PM2.5 tertinggi & Plot negara dengan PM2.5 terendah

# %%
# Menghitung rata-rata PM2.5 per-negara
top_dirty = (
    final_df.groupby("Country")["PM25"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

top_clean = (
    final_df.groupby("Country")["PM25"]
    .mean()
    .sort_values()
    .head(10)
)

# Plot negara dengan PM2.5 tertinggi
plt.figure(figsize=(12,5))
sns.barplot(x=top_dirty.values, y=top_dirty.index, palette="Reds_r")
plt.title("10 Negara dengan Rata-rata PM2.5 Tertinggi (2010–2019)")
plt.xlabel("Rata-rata PM2.5")
plt.ylabel("Negara")
plt.savefig("top_dirty_countries.png", dpi=300, bbox_inches='tight')
plt.show()

# Plot negara dengan PM2.5 terendah
plt.figure(figsize=(12,5))
sns.barplot(x=top_clean.values, y=top_clean.index, palette="Blues")
plt.title("10 Negara dengan Rata-rata PM2.5 Terendah (2010–2019)")
plt.xlabel("Rata-rata PM2.5")
plt.ylabel("Negara")
plt.savefig("top_clean_countries.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipython-input-1797296783.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_dirty.values, y=top_dirty.index, palette="Reds_r")
# /tmp/ipython-input-1797296783.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_clean.values, y=top_clean.index, palette="Blues")
